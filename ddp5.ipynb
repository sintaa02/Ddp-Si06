# %%
pilih = int(input("""Selamat datang di aplikasi menghitung
1. Untuk menghitung luas persegi
2. untuk menghitung luas lingkaran
3. Untuk menghitung luas segitiga
masukan pilihan anda : """))

match pilih:
 case 1 :
   print("Kamu memilih 1 untuk menghitung luas persegi")
   sisi = int(input("masukan sisi persegi"))
   luas_Psg = sisi*sisi
   print("luas persegi yang sisinya",sisi,"adalah",luas_Psg)
 case 2 :
   print("Kamu memilih 2 untuk menghitung lingkaran")
   jari_jari = int(input("masukan jari jarinya"))
   luas_Lkr = 3.14 * jari_jari * jari_jari
   print("luas lingkaran yang jari jarinya",jari_jari,"adalah",luas_Lkr)
 case 3 :
   print("Kamu memilih 3 untuk menghitung segitiga")
   alas = int(input("masukan alas segitiga"))
   tinggi = int(input("masukan tinggi segitiga"))
   luas_Segitiga = 0.5 * alas * tinggi
   print("luas segitiga dengan alas",alas,"dan tinggi",tinggi,"adalah",luas_Segitiga)
 case _ :
  print("Pilian anda salah")
# Out:
# Selamat datang di aplikasi menghitung
# 1. Untuk menghitung luas persegi
# 2. untuk menghitung luas lingkaran
# 3. Untuk menghitung luas segitiga
# masukan pilihan anda : 4
# Pilian anda salah

# %%
kendaraan= {"nama kendaraan" : "motor", "jenis kendaraan": "scooter", "cc kendaraan" : "109,5", "warna kendaraan" : "putih", "roda kendaraan": "roda dua"}
print(kendaraan)
# Out:
# {'nama kendaraan': 'motor', 'jenis kendaraan': 'scooter', 'cc kendaraan': '109,5', 'warna kendaraan': 'putih', 'roda kendaraan': 'roda dua'}

# %%
List_1 = ["nama kendaraan", "jenis kendaraan", "cc kendaran", "warna kendaraan", "roda kendaraan"]
print(List_1)
List_2= "harga kendaraan","tipe kendaraan"
List_1.append(List_2)
print(List_1)
# Out:
# ['nama kendaraan', 'jenis kendaraan', 'cc kendaran', 'warna kendaraan', 'roda kendaraan']
# ['nama kendaraan', 'jenis kendaraan', 'cc kendaran', 'warna kendaraan', 'roda kendaraan', ('harga kendaraan', 'tipe kendaraan')]

# %%
list= ["nama kendaraan", "jenis kendaraan", "cc kendaran", "warna kendaraan", "roda kendaran"]
print(list)
list.append("harga kendaraan")
print(list)
list.append("tipe kendaraan")
print(list)
list.insert(2,"merk kendaraan")
print(list)
# Out:
# ['nama kendaraan', 'jenis kendaraan', 'cc kendaran', 'warna kendaraan', 'roda kendaran']
# ['nama kendaraan', 'jenis kendaraan', 'cc kendaran', 'warna kendaraan', 'roda kendaran', 'harga kendaraan']
# ['nama kendaraan', 'jenis kendaraan', 'cc kendaran', 'warna kendaraan', 'roda kendaran', 'harga kendaraan', 'tipe kendaraan']
# ['nama kendaraan', 'jenis kendaraan', 'merk kendaraan', 'cc kendaran', 'warna kendaraan', 'roda kendaran', 'harga kendaraan', 'tipe kendaraan']
